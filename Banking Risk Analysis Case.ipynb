# %% [markdown]
# # Exploratory Data Analysis
#
# Developing a basic understanding of risk analytics in banking and financial services an understand how data is used to minimise the risk of losing money while lending to customers

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import pandas as pd
import pymysql

conn = pymysql.connect(
    host="127.0.0.1",
    user="root",
    password="Eshika",
    database="banking_case"
)

query="SELECT * FROM customers;"
df=pd.read_sql(query,conn)

conn.close()
# Out:
# C:\Users\mishr\AppData\Local\Temp\ipykernel_1440\3120057153.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
# Generating descriptive statistics for the dataframe
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %% [markdown]
# # Univariate Analysis

# %%
bins=[0,100000,300000,float("inf")]
labels=["Low","Mid","High"]
df["Income Band"]=pd.cut(df["Estimated Income"],bins=bins,labels=labels,right=False)

# %%
ax = df["Income Band"].value_counts().plot(kind="bar")
ax.set_xlabel("Income Band")
# Out:
# Text(0.5, 0, 'Income Band')

# %%
categorical_cols=df[["BRId","GenderId","Amount of Credit Cards","Nationality","Fee Structure","Loyalty Classification","Occupation","Properties Owned","Risk Weighting","IAId","Income Band"]].columns

for col in categorical_cols:
    print(f"Value Counts for '{col}':")
    display(df[col].value_counts().to_frame())
# Out:
# Value Counts for 'BRId':
#    BRId
# 3  1352
# 1   660
# 2   495
# 4   493
# Value Counts for 'GenderId':
#    GenderId
# 2      1512
# 1      1488
# Value Counts for 'Amount of Credit Cards':
#    Amount of Credit Cards
# 1                    1922
# 2                     765
# 3                     313
# Value Counts for 'Nationality':
#             Nationality
# European           1309
# Asian               754
# American            507
# Australian          254
# African             176
# Value Counts for 'Fee Structure':
#       Fee Structure
# High           1476
# Mid             962
# Low             562
# Value Counts for 'Loyalty Classification':
#           Loyalty Classification
# Jade                        1331
# Silver                       767
# Gold                         585
# Platinum                     317
# Value Counts for 'Occupation':
#                               Occupation
# Structural Analysis Engineer          28
# ...

# %%
# Examine the distribution of unique categories in categorical columns

for i, predictor in enumerate(df[["BRId","GenderId","Amount of Credit Cards","Nationality","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","IAId","Income Band"]].columns
):
    plt.figure(i)
    sns.countplot(data=df,x=predictor)

# %% [markdown]
# # Bivariate Analysis

# %%
for i, predictor in enumerate(df[["BRId","GenderId","Amount of Credit Cards","Nationality","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","IAId","Income Band"]].columns
):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='GenderId')

# %%
for i, predictor in enumerate(df[["BRId","GenderId","Amount of Credit Cards","Nationality","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","IAId","Income Band"]].columns
):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='Nationality')

# %%
for col in categorical_cols:
    if col == "Occupation":
        continue
    plt.figure(figsize=(8,4))
    sns.histplot(df[col])
    plt.title('Histogram of Occupation Count')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# # Numerical Analysis

# %%
# Univariate Analysis and Visualization
numerical_cols=["Estimated Income","Superannuation Savings","Credit Card Balance","Bank Loans","Bank Deposits","Checking Accounts","Saving Accounts","Foreign Currency Account","Business Lending"]
plt.figure(figsize=(20,20))
for i,col in enumerate(numerical_cols):
    plt.subplot(4,3,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(col)
plt.show()

# %% [markdown]
# # Heatmaps

# %%
correlation_matrix=df[numerical_cols].corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation_matrix,annot=True,cmap='crest',fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Insights from the EDA
#
# 1.Bank Deposits and Checking Accounts (0.84): Very strong positive correlation, indicating that customers with higher bank deposits also tend to maintain higher checking account balances.
#
# 2.Bank Deposits and Saving Accounts (0.75): Strong positive correlation, suggesting that customers who grow their deposits also increase their savings simultaneously.
#
# 3.Business Lending and Bank Deposits (0.44): Customers with higher deposits are more likely to engage in business lending.
#
# 4.Business Lending and Bank Loans (0.42): Strong link between different forms of lending/credit.
#
# 5.Credit Card Balance and Bank Deposits (0.38), Credit Card Balance and Bank Loans (0.37): Moderate relationship between credit card usage and both deposits and loans.
#
# 6.Foreign Currency shows moderate correlations with Bank Deposits (0.41), Bank Loans (0.36), and Business Lending (0.37). This indicates that customers with foreign currency accounts are often more engaged with deposits and lending activities.

# %% [markdown]
# # Implications for Banking Risk Analysis
#
# 1.Checking accounts, savings accounts, and bank deposits are tightly linked, forming a natural cluster of related financial activities.
#
# 2.Business lending, bank loans, and credit card balances cluster together, highlighting a segment of customers with higher credit risk exposure.
#
# 3.Superannuation savings and estimated income are relatively independent, contributing less to cross-selling opportunities or predictive risk modeling.
